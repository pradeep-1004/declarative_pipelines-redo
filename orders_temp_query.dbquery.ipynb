-- %%
CREATE TABLE orders
(
  order_id INT,
  order_date DATE,
  customer_id INT,
  order_status STRING
);

-- INSERT INTO orders VALUES
-- (1, '2020-01-01', 1, 'PENDING'),
-- (2, '2020-01-02', 2, 'DELIVERED'),
-- (3, '2020-01-03', 3, 'CANCELLED'),
-- (4, '2020-01-04', 4, 'DELIVERED'),
-- (5, '2020-01-05', 5, 'PENDING');  


SELECT * FROM orders;


-- insert additional values
INSERT INTO orders VALUES
(6, '2020-01-06', 6, 'DELIVERED'),
(7, '2020-01-07', 7, 'CANCELLED'),
(8, '2020-01-08', 8, 'DELIVERED');
